# %%
import pandas as pd
import os 

def merge_df():
    # Définir les dossiers sources
    cleaned_adzuna = '/run/media/dinasoa/b4c37e5f-ad8f-4388-a46b-666dc08d1a12/COURS_HEI/DONNEES2/DONNEES2_PROJET/TRAITEMENT/jobs-etl/merged/adzuna-main.csv'
    cleaned_pole = '/run/media/dinasoa/b4c37e5f-ad8f-4388-a46b-666dc08d1a12/COURS_HEI/DONNEES2/DONNEES2_PROJET/TRAITEMENT/jobs-etl/merged/pole-emploi-main.csv'
    adzuna_list = []  # Liste pour les dataframes d'adzuna
    pole_list = []  # Liste pour les dataframes de pole

    df1 = pd.read_csv(cleaned_adzuna)
    df2 = pd.read_csv(cleaned_pole)
    
    df_merged = pd.concat([df1, df2], ignore_index=True)

    
    print(df_merged)
    
    df_merged.to_csv(f'/run/media/dinasoa/b4c37e5f-ad8f-4388-a46b-666dc08d1a12/COURS_HEI/DONNEES2/DONNEES2_PROJET/TRAITEMENT/data.csv', index=False)

merge_df()
# Out:
#                       created  salary_max          id  \
# 0        2023-06-29T01:53:15Z     60000.0  4175453938
# 1        2023-07-17T11:25:50Z     60000.0  4209881425
# 2        2023-06-27T19:58:45Z     80000.0  4173539776
# 3        2023-06-28T01:09:14Z     60000.0  4173966092
# 4        2023-08-03T07:20:01Z         NaN  4239644983
# ..                        ...         ...         ...
# 977  2023-08-08T09:22:11.000Z         NaN     159MNKB
# 978  2023-08-08T07:23:21.000Z         NaN     159MKZW
# 979  2023-08-07T18:21:12.000Z         NaN     159MHJT
# 980  2023-08-07T17:54:17.000Z         NaN     159MGZQ
# 981  2022-09-25T07:41:15.000Z         NaN      787364
#
#                                                  title  salary_min  \
# 0                                   Expert Réseau/Wifi     40000.0
# 1    Ingénieur Système - Surveillance et Renseignem...     40000.0
# 2          Ingénieur développement logiciel C++ sénior     60000.0
# ...
