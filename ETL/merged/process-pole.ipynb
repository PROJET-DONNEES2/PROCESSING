# %%
import pandas as pd

# %%
df = pd.read_csv("pole-emploi-main.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df = pd.read_csv("pole-emploi-main.csv")
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df
# Out:
#           id                                           intitule  \
# 0    159SRQR  Réparateur / Réparatrice en smartphone, téléph...
# 1    159SRNH          Technicien maintenance informatique (F/H)
# 2    159SQRG                       Technicien helpdesk N1 (H/F)
# 3    159SQQD                         Technicien Help Desk (F/H)
# 4    159SPXG              Technicien Support Informatique (h/f)
# ..       ...                                                ...
# 577  5713455  Technicien / Technicienne de maintenance en ma...
# 578  4138508  Technicien / Technicienne de hot line en infor...
# 579  3648306  Technicien / Technicienne de maintenance en ma...
# 580  143DWJT  Technicien dépanneur / Technicienne dépanneuse...
# 581   787364  Technicien / Technicienne de maintenance en ma...
#
#                                            description  \
# 0    Au sein d'un magasin "Rennes Mobile Shop" de v...
# 1    Dans le cadre de poste, vous assurez des actio...
# ...
